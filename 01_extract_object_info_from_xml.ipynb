# %%
import os
from glob import glob
import pandas as pd
from functools import reduce
from xml.etree import ElementTree as et

# %%
#step-1: get path of each xmlfile
xmlfiles = glob('./data_images/*.xml')
#replace \\ with /
replace_text = lambda x: x.replace('\\','/')
xmlfiles = list(map(replace_text,xmlfiles))

# %%
xmlfiles
# Out:
# ['./data_images/D (1).xml',
#  './data_images/D (10).xml',
#  './data_images/D (100).xml',
#  './data_images/D (11).xml',
#  './data_images/D (12).xml',
#  './data_images/D (13).xml',
#  './data_images/D (14).xml',
#  './data_images/D (15).xml',
#  './data_images/D (16).xml',
#  './data_images/D (17).xml',
#  './data_images/D (18).xml',
#  './data_images/D (19).xml',
#  './data_images/D (2).xml',
#  './data_images/D (20).xml',
#  './data_images/D (21).xml',
#  './data_images/D (22).xml',
#  './data_images/D (23).xml',
#  './data_images/D (24).xml',
#  './data_images/D (25).xml',
#  './data_images/D (26).xml',
#  './data_images/D (27).xml',
#  './data_images/D (28).xml',
#  './data_images/D (29).xml',
#  './data_images/D (3).xml',
#  './data_images/D (30).xml',
#  './data_images/D (31).xml',
#  './data_images/D (32).xml',
#  './data_images/D (33).xml',
#  './data_images/D (34).xml',
#  './data_images/D (35).xml',
#  './data_images/D (36).xml',
#  './data_images/D (37).xml',
#  './data_images/D (38).xml',
#  './data_images/D (39).xml',
#  './data_images/D (4).xml',
#  './data_images/D (40).xml',
#  './data_images/D (41).xml',
#  './data_images/D (42).xml',
#  './data_images/D (43).xml',
#  './data_images/D (44).xml',
#  './data_images/D (45).xml',
#  './data_images/D (46).xml',
#  './data_images/D (47).xml',
#  './data_images/D (48).xml',
#  './data_images/D (49).xml',
#  './data_images/D (5).xml',
#  './data_images/D (50).xml',
#  './data_images/D (51).xml',
#  './data_images/D (52).xml',
#  './data_images/D (53).xml',
#  './data_images/D (54).xml',
#  './data_images/D (55).xml',
#  './data_images/D (56).xml',
#  './data_images/D (57).xml',
#  './data_images/D (58).xml',
#  './data_images/D (59).xml',
#  './data_images/D (6).xml',
#  './data_images/D (60).xml',
#  './data_images/D (61).xml',
#  './data_images/D (62).xml',
#  './data_images/D (63).xml',
#  './data_images/D (64).xml',
#  './data_images/D (65).xml',
#  './data_images/D (66).xml',
#  './data_images/D (67).xml',
#  './data_images/D (68).xml',
#  './data_images/D (69).xml',
#  './data_images/D (7).xml',
#  './data_images/D (70).xml',
#  './data_images/D (71).xml',
#  './data_images/D (72).xml',
#  './data_images/D (73).xml',
#  './data_images/D (74).xml',
#  './data_images/D (75).xml',
#  './data_images/D (76).xml',
#  './data_images/D (77).xml',
#  './data_images/D (78).xml',
#  './data_images/D (79).xml',
#  './data_images/D (8).xml',
#  './data_images/D (80).xml',
#  './data_images/D (81).xml',
#  './data_images/D (82).xml',
#  './data_images/D (84).xml',
#  './data_images/D (85).xml',
#  './data_images/D (86).xml',
#  './data_images/D (87).xml',
#  './data_images/D (88).xml',
#  './data_images/D (89).xml',
#  './data_images/D (9).xml',
#  './data_images/D (90).xml',
#  './data_images/D (91).xml',
#  './data_images/D (92).xml',
#  './data_images/D (93).xml',
#  './data_images/D (94).xml',
#  './data_images/D (95).xml',
#  './data_images/D (96).xml',
#  './data_images/D (97).xml',
#  './data_images/D (98).xml',
#  './data_images/D (99).xml',
#  './data_images/H (1).xml',
#  './data_images/H (10).xml',
#  './data_images/H (100).xml',
#  './data_images/H (11).xml',
#  './data_images/H (12).xml',
#  './data_images/H (13).xml',
#  './data_images/H (14).xml',
#  './data_images/H (15).xml',
#  './data_images/H (16).xml',
#  './data_images/H (17).xml',
#  './data_images/H (18).xml',
#  './data_images/H (19).xml',
#  './data_images/H (2).xml',
#  './data_images/H (20).xml',
#  './data_images/H (21).xml',
#  './data_images/H (22).xml',
#  './data_images/H (23).xml',
#  './data_images/H (24).xml',
#  './data_images/H (25).xml',
#  './data_images/H (26).xml',
#  './data_images/H (27).xml',
#  './data_images/H (28).xml',
#  './data_images/H (29).xml',
#  './data_images/H (30).xml',
#  './data_images/H (31).xml',
#  './data_images/H (32).xml',
#  './data_images/H (33).xml',
#  './data_images/H (34).xml',
#  './data_images/H (35).xml',
#  './data_images/H (36).xml',
#  './data_images/H (37).xml',
#  './data_images/H (38).xml',
#  './data_images/H (39).xml',
#  './data_images/H (4).xml',
#  './data_images/H (40).xml',
#  './data_images/H (41).xml',
#  './data_images/H (42).xml',
#  './data_images/H (43).xml',
#  './data_images/H (44).xml',
#  './data_images/H (45).xml',
#  './data_images/H (46).xml',
#  './data_images/H (47).xml',
#  './data_images/H (48).xml',
#  './data_images/H (49).xml',
#  './data_images/H (5).xml',
#  './data_images/H (50).xml',
#  './data_images/H (51).xml',
#  './data_images/H (52).xml',
#  './data_images/H (53).xml',
#  './data_images/H (54).xml',
#  './data_images/H (55).xml',
#  './data_images/H (56).xml',
#  './data_images/H (57).xml',
#  './data_images/H (58).xml',
#  './data_images/H (59).xml',
#  './data_images/H (6).xml',
#  './data_images/H (60).xml',
#  './data_images/H (61).xml',
#  './data_images/H (62).xml',
#  './data_images/H (63).xml',
#  './data_images/H (64).xml',
#  './data_images/H (65).xml',
#  './data_images/H (66).xml',
#  './data_images/H (67).xml',
#  './data_images/H (68).xml',
#  './data_images/H (69).xml',
#  './data_images/H (7).xml',
#  './data_images/H (70).xml',
#  './data_images/H (71).xml',
#  './data_images/H (72).xml',
#  './data_images/H (73).xml',
#  './data_images/H (74).xml',
#  './data_images/H (75).xml',
#  './data_images/H (76).xml',
#  './data_images/H (77).xml',
#  './data_images/H (78).xml',
#  './data_images/H (79).xml',
#  './data_images/H (8).xml',
#  './data_images/H (80).xml',
#  './data_images/H (81).xml',
#  './data_images/H (82).xml',
#  './data_images/H (83).xml',
#  './data_images/H (84).xml',
#  './data_images/H (85).xml',
#  './data_images/H (86).xml',
#  './data_images/H (87).xml',
#  './data_images/H (88).xml',
#  './data_images/H (89).xml',
#  './data_images/H (9).xml',
#  './data_images/H (90).xml',
#  './data_images/H (91).xml',
#  './data_images/H (92).xml',
#  './data_images/H (93).xml',
#  './data_images/H (94).xml',
#  './data_images/H (95).xml',
#  './data_images/H (96).xml',
#  './data_images/H (97).xml',
#  './data_images/H (98).xml',
#  './data_images/H (99).xml',
#  './data_images/V (1).xml',
#  './data_images/V (10).xml',
#  './data_images/V (100).xml',
#  './data_images/V (11).xml',
#  './data_images/V (12).xml',
#  './data_images/V (13).xml',
#  './data_images/V (14).xml',
#  './data_images/V (15).xml',
#  './data_images/V (16).xml',
#  './data_images/V (17).xml',
#  './data_images/V (18).xml',
#  './data_images/V (19).xml',
#  './data_images/V (2).xml',
#  './data_images/V (20).xml',
#  './data_images/V (21).xml',
#  './data_images/V (22).xml',
#  './data_images/V (23).xml',
#  './data_images/V (24).xml',
#  './data_images/V (25).xml',
#  './data_images/V (26).xml',
#  './data_images/V (27).xml',
#  './data_images/V (28).xml',
#  './data_images/V (29).xml',
#  './data_images/V (3).xml',
#  './data_images/V (30).xml',
#  './data_images/V (31).xml',
#  './data_images/V (32).xml',
#  './data_images/V (33).xml',
#  './data_images/V (34).xml',
#  './data_images/V (35).xml',
#  './data_images/V (36).xml',
#  './data_images/V (37).xml',
#  './data_images/V (38).xml',
#  './data_images/V (39).xml',
#  './data_images/V (4).xml',
#  './data_images/V (40).xml',
#  './data_images/V (41).xml',
#  './data_images/V (42).xml',
#  './data_images/V (43).xml',
#  './data_images/V (44).xml',
#  './data_images/V (45).xml',
#  './data_images/V (46).xml',
#  './data_images/V (47).xml',
#  './data_images/V (48).xml',
#  './data_images/V (49).xml',
#  './data_images/V (5).xml',
#  './data_images/V (50).xml',
#  './data_images/V (51).xml',
#  './data_images/V (52).xml',
#  './data_images/V (53).xml',
#  './data_images/V (54).xml',
#  './data_images/V (55).xml',
#  './data_images/V (56).xml',
#  './data_images/V (57).xml',
#  './data_images/V (58).xml',
#  './data_images/V (59).xml',
#  './data_images/V (6).xml',
#  './data_images/V (60).xml',
#  './data_images/V (61).xml',
#  './data_images/V (62).xml',
#  './data_images/V (63).xml',
#  './data_images/V (64).xml',
#  './data_images/V (65).xml',
#  './data_images/V (66).xml',
#  './data_images/V (67).xml',
#  './data_images/V (68).xml',
#  './data_images/V (69).xml',
#  './data_images/V (7).xml',
#  './data_images/V (70).xml',
#  './data_images/V (71).xml',
#  './data_images/V (72).xml',
#  './data_images/V (73).xml',
#  './data_images/V (74).xml',
#  './data_images/V (75).xml',
#  './data_images/V (76).xml',
#  './data_images/V (77).xml',
#  './data_images/V (78).xml',
#  './data_images/V (79).xml',
#  './data_images/V (8).xml',
#  './data_images/V (80).xml',
#  './data_images/V (81).xml',
#  './data_images/V (82).xml',
#  './data_images/V (83).xml',
#  './data_images/V (84).xml',
#  './data_images/V (85).xml',
#  './data_images/V (86).xml',
#  './data_images/V (87).xml',
#  './data_images/V (88).xml',
#  './data_images/V (89).xml',
#  './data_images/V (9).xml',
#  './data_images/V (90).xml',
#  './data_images/V (91).xml',
#  './data_images/V (92).xml',
#  './data_images/V (93).xml',
#  './data_images/V (94).xml',
#  './data_images/V (95).xml',
#  './data_images/V (96).xml',
#  './data_images/V (97).xml',
#  './data_images/V (98).xml',
#  './data_images/V (99).xml']

# %%
#step-2: read xml files
#from each xml file we need to extract
#filename, size(wicth, height), object(nam,xmin,xmax,ymin,ymax)
def extract_text(filename):
    tree = et.parse(filename)
    root = tree.getroot()

    #extract file name
    image_name = root.find('filename').text
    #width and height of the image
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    objs = root.findall('object')
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append([image_name,width,height,name,xmin,xmax,ymin,ymax])
    return parser

# %%
parser_all = list(map(extract_text,xmlfiles))

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
df = pd.DataFrame(data,columns = ['filename','width','height','name','xmin','xmax','ymin','ymax'])

# %%
df.head()
# Out:
#       filename width height            name xmin xmax ymin ymax
# 0    D (1).jpg   227    227  Retak Diagonal    1  227    1  175
# 1   D (10).jpg   227    227  Retak Diagonal   40  227  103  227
# 2  D (100).jpg   227    227  Retak Diagonal    1  227   72  227
# 3   D (11).jpg   227    227  Retak Diagonal    1  227   56  227
# 4   D (12).jpg   227    227  Retak Diagonal    1  227    1  227

# %%
df.shape
# Out:
# (318, 8)

# %%
df['name'].value_counts()
# Out:
# name
# Retak Diagonal      138
# Retak Vertikal       90
# Retak Horizontal     90
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  318 non-null    object
#  1   width     318 non-null    object
#  2   height    318 non-null    object
#  3   name      318 non-null    object
#  4   xmin      318 non-null    object
#  5   xmax      318 non-null    object
#  6   ymin      318 non-null    object
#  7   ymax      318 non-null    object
# dtypes: object(8)
# memory usage: 20.0+ KB

# %%
#type conversion
cols = ['width','height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  318 non-null    object
#  1   width     318 non-null    int32
#  2   height    318 non-null    int32
#  3   name      318 non-null    object
#  4   xmin      318 non-null    int32
#  5   xmax      318 non-null    int32
#  6   ymin      318 non-null    int32
#  7   ymax      318 non-null    int32
# dtypes: int32(6), object(2)
# memory usage: 12.5+ KB

# %%
# center x, center y
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']

# w
df['w'] = (df['xmax']-df['xmin'])/df['width']
# h
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#       filename  width  height            name  xmin  xmax  ymin  ymax  \
# 0    D (1).jpg    227     227  Retak Diagonal     1   227     1   175
# 1   D (10).jpg    227     227  Retak Diagonal    40   227   103   227
# 2  D (100).jpg    227     227  Retak Diagonal     1   227    72   227
# 3   D (11).jpg    227     227  Retak Diagonal     1   227    56   227
# 4   D (12).jpg    227     227  Retak Diagonal     1   227     1   227
#
#    center_x  center_y         w         h
# 0  0.502203  0.387665  0.995595  0.766520
# 1  0.588106  0.726872  0.823789  0.546256
# 2  0.502203  0.658590  0.995595  0.682819
# 3  0.502203  0.623348  0.995595  0.753304
# 4  0.502203  0.502203  0.995595  0.995595

# %%
images = df['filename'].unique()

# %%
len(images)
# Out:
# 298

# %%
# 80% train and 20% test
img_df = pd.DataFrame(images, columns=['filename'])
img_train = tuple(img_df.sample(frac=0.8)['filename']) # shuffle and pick 80% of images

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename']) # take rest 20% images

# %%
len(img_train), len(img_test)
# Out:
# (238, 60)

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#      filename  width  height            name  xmin  xmax  ymin  ymax  \
# 1  D (10).jpg    227     227  Retak Diagonal    40   227   103   227
# 4  D (12).jpg    227     227  Retak Diagonal     1   227     1   227
# 5  D (13).jpg    227     227  Retak Diagonal     1   227    71   227
# 6  D (14).jpg    227     227  Retak Diagonal     7   158     1   227
# 8  D (16).jpg    227     227  Retak Diagonal    34   227    16   227
#
#    center_x  center_y         w         h
# 1  0.588106  0.726872  0.823789  0.546256
# 4  0.502203  0.502203  0.995595  0.995595
# 5  0.502203  0.656388  0.995595  0.687225
# 6  0.363436  0.502203  0.665198  0.995595
# 8  0.574890  0.535242  0.850220  0.929515

# %%
test_df.head()
# Out:
#        filename  width  height            name  xmin  xmax  ymin  ymax  \
# 0     D (1).jpg    227     227  Retak Diagonal     1   227     1   175
# 2   D (100).jpg    227     227  Retak Diagonal     1   227    72   227
# 3    D (11).jpg    227     227  Retak Diagonal     1   227    56   227
# 7    D (15).jpg    227     227  Retak Diagonal     1   227    30   130
# 11   D (19).jpg    227     227  Retak Vertikal    28   151     1   227
#
#     center_x  center_y         w         h  id
# 0   0.502203  0.387665  0.995595  0.766520   0
# 2   0.502203  0.658590  0.995595  0.682819   0
# 3   0.502203  0.623348  0.995595  0.753304   0
# 7   0.502203  0.352423  0.995595  0.440529   0
# 11  0.394273  0.502203  0.541850  0.995595   1

# %%
# Label encoding
def label_encoding(x):
    labels = {'Retak Diagonal':0,'Retak Vertikal':1,'Retak Horizontal':2}
    return labels[x]

# %%
train_df.loc[:, ['id', 'name']] = train_df[['id', 'name']]
test_df.loc[:, ['id', 'name']] = test_df[['id', 'name']]

# %%
train_df.head(10)
# Out:
#       filename  width  height            name  xmin  xmax  ymin  ymax  \
# 1   D (10).jpg    227     227  Retak Diagonal    40   227   103   227
# 4   D (12).jpg    227     227  Retak Diagonal     1   227     1   227
# 5   D (13).jpg    227     227  Retak Diagonal     1   227    71   227
# 6   D (14).jpg    227     227  Retak Diagonal     7   158     1   227
# 8   D (16).jpg    227     227  Retak Diagonal    34   227    16   227
# 9   D (17).jpg    227     227  Retak Diagonal    15   226     1   156
# 10  D (18).jpg    227     227  Retak Vertikal    23   125     1   227
# 12   D (2).jpg    227     227  Retak Diagonal     1   194    10   227
# 13  D (20).jpg    227     227  Retak Diagonal    43   127     1   227
# 15  D (22).jpg    227     227  Retak Diagonal     1   222   115   227
#
#     center_x  center_y         w         h  id
# 1   0.588106  0.726872  0.823789  0.546256   0
# 4   0.502203  0.502203  0.995595  0.995595   0
# 5   0.502203  0.656388  0.995595  0.687225   0
# 6   0.363436  0.502203  0.665198  0.995595   0
# 8   0.574890  0.535242  0.850220  0.929515   0
# 9   0.530837  0.345815  0.929515  0.682819   0
# 10  0.325991  0.502203  0.449339  0.995595   1
# 12  0.429515  0.522026  0.850220  0.955947   0
# 13  0.374449  0.502203  0.370044  0.995595   0
# 15  0.491189  0.753304  0.973568  0.493392   0

# %%
import os
from shutil import move

# %%
train_folder = 'data_images/train'
test_folder = 'data_images/test'
    
os.mkdir(train_folder)
os.mkdir(test_folder)

# %%
cols = ['filename', 'id', 'center_x', 'center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
#groupby_obj_train.get_group('D (10).jpg').set_index('filename').to_csv('sample.txt',index=False,header=False)
#save each image in train/test folder and repective labels in .txt
def save_data(filename, folder_path, group_obj):
    #move image
    src = os.path.join('data_images',filename)
    dst = os.path.join(folder_path,filename)
    move(src,dst)
    
    #save the labels
    text_filename = os.path.join(folder_path, os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 233    None
# 234    None
# 235    None
# 236    None
# 237    None
# Length: 238, dtype: object

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\shutil.py:815, in move(src, dst, copy_function)
#     814 try:
# --> 815     os.rename(src, real_dst)
#     816 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'data_images\\D (1).jpg' -> 'data_images/test\\D (1).jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [232], line 2
#       1 filename_series_test = pd.Series(groupby_obj_test.groups.keys())
# ----> 2 filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1496, in SeriesApply.apply_standard.<locals>.curried(x)
#    1495 def curried(x):
# -> 1496     return func(x, *self.args, **self.kwargs)
#
# Cell In [223], line 7, in save_data(filename, folder_path, group_obj)
#       5 src = os.path.join('data_images',filename)
#       6 dst = os.path.join(folder_path,filename)
# ----> 7 move(src,dst)
#       9 #save the labels
#      10 text_filename = os.path.join(folder_path, os.path.splitext(filename)[0]+'.txt')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\shutil.py:835, in move(src, dst, copy_function)
#     833         rmtree(src)
#     834     else:
# --> 835         copy_function(src, real_dst)
#     836         os.unlink(src)
#     837 return real_dst
#
# File ~\AppData\Local\Programs\Python\Python310\lib\shutil.py:434, in copy2(src, dst, follow_symlinks)
#     432 if os.path.isdir(dst):
#     433     dst = os.path.join(dst, os.path.basename(src))
# --> 434 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     435 copystat(src, dst, follow_symlinks=follow_symlinks)
#     436 return dst
#
# File ~\AppData\Local\Programs\Python\Python310\lib\shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
#     256             with open(dst, 'wb') as fdst:
#     257                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_images\\D (1).jpg'
